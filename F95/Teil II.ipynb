# %% [markdown]
# ## Medizinische Bildanalyse

# %%
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import numpy as np
from scipy.optimize import curve_fit

# %%
col1, wert1 = np.loadtxt('./multi_histBins_5.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col2, wert2 = np.loadtxt('./multi_histBins_10.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col3, wert3 = np.loadtxt('./multi_histBins_15.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col4, wert4 = np.loadtxt('./multi_histBins_20.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col5, wert5 = np.loadtxt('./multi_histBins_25.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col6, wert6 = np.loadtxt('./multi_histBins_30.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col7, wert7 = np.loadtxt('./multi_histBins_35.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col8, wert8 = np.loadtxt('./multi_histBins_40.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col9, wert9 = np.loadtxt('./multi_histBins_45.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col10, wert10 = np.loadtxt('./multi_histBins_50.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col11, wert11 = np.loadtxt('./multi_histBins_55.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col12, wert12 = np.loadtxt('./multi_histBins_60.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col13, wert13 = np.loadtxt('./multi_histBins_65.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col14, wert14 = np.loadtxt('./multi_histBins_70.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col15, wert15 = np.loadtxt('./multi_histBins_75.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col16, wert16 = np.loadtxt('./multi_histBins_80.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col17, wert17 = np.loadtxt('./multi_histBins_85.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col18, wert18 = np.loadtxt('./multi_histBins_90.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col19, wert19 = np.loadtxt('./multi_histBins_95.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
col20, wert20 = np.loadtxt('./multi_histBins_100.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)

# %%
plt.plot(col1,wert1, linestyle = 'None', label = 'Bins 5', marker = '.')
#plt.plot(col2,wert2, linestyle = 'None', label = 'Bins 10', marker = '.')
plt.plot(col3,wert3, linestyle = 'None', label = 'Bins 15', marker = '.')
#plt.plot(col4,wert4, linestyle = 'None', label = 'Bins 20', marker = '.')
plt.plot(col5,wert5, linestyle = 'None', label = 'Bins 25', marker = '.')
#plt.plot(col6,wert6, linestyle = 'None', label = 'Bins 30', marker = '.')
plt.plot(col7,wert7, linestyle = 'None', label = 'Bins 35', marker = '.')
#plt.plot(col8,wert8, linestyle = 'None', label = 'Bins 40', marker = '.')
plt.plot(col9,wert9, linestyle = 'None', label = 'Bins 45', marker = '.')
#plt.plot(col10,wert10, linestyle = 'None', label = 'Bins 50', marker = '.')
plt.plot(col11,wert11, linestyle = 'None', label = 'Bins 55', marker = '.')
#plt.plot(col12,wert12, linestyle = 'None', label = 'Bins 60', marker = '.')
plt.plot(col13,wert13, linestyle = 'None', label = 'Bins 65', marker = '.')
#plt.plot(col14,wert14, linestyle = 'None', label = 'Bins 70', marker = '.')
plt.plot(col15,wert15, linestyle = 'None', label = 'Bins 75', marker = '.')
#plt.plot(col16,wert16, linestyle = 'None', label = 'Bins 80', marker = '.')
plt.plot(col17,wert17, linestyle = 'None', label = 'Bins 85', marker = '.')
#plt.plot(col18,wert18, linestyle = 'None', label = 'Bins 90', marker = '.')
plt.plot(col19,wert19, linestyle = 'None', label = 'Bins 95', marker = '.')
plt.plot(col20,wert20, linestyle = 'None', label = 'Bins 100', marker = '.')


plt.xlabel('Parameter Wert', fontsize = 13)
plt.ylabel('MI-Metrik Wert', fontsize = 13)
plt.title('Veranderung der Bin-Anzahl bei MI', fontsize = 18)
plt.legend(loc="best")
plt.grid()

plt.show()

# %%
mon_mi0, wert_mi0 = np.loadtxt('./mono_MI_parameter_0.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
mon_msd0, wert_msd0 = np.loadtxt('./mono_MSD_parameter_0.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)

fig, ax1 = plt.subplots()
color = 'tab:red'

ax1.plot(mon_mi0, wert_mi0, linestyle = 'None', label = 'MI', marker = '.')
ax1.set_xlabel('Parameter Wert', fontsize = 13)
ax1.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax1.tick_params(axis='y', labelcolor=color)

color = 'tab:blue'
ax2 = ax1.twinx()

ax2.plot(mon_msd0, wert_msd0, linestyle = 'None', label = 'MSD', marker = '.')
ax2.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Parameter 0 (Rotation); Monomodal", fontsize = 15)
plt.legend(loc="best")

plt.show()

# %%
mon_mi3, wert_mi3 = np.loadtxt('./mono_MI_parameter_3.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
mon_msd3, wert_msd3 = np.loadtxt('./mono_MSD_parameter_3.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)

fig, ax1 = plt.subplots()
color = 'tab:red'

ax1.plot(mon_mi3, wert_mi3, linestyle = 'None', label = 'MI', marker = '.', color=color)
ax1.set_xlabel('Parameter Wert', fontsize = 13)
ax1.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax1.tick_params(axis='y', labelcolor=color)

color = 'tab:blue'
ax2 = ax1.twinx()

ax2.plot(mon_msd3, wert_msd3, linestyle = 'None', label = 'MSD', marker = '.', color=color)
ax2.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Parameter 3 (Translation); Monomodal", fontsize = 15)
plt.legend(loc="best")

plt.show()

# %%
mul_mi0, wert_mi0 = np.loadtxt('./multi_MI_parameter_0.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
mul_msd0, wert_msd0 = np.loadtxt('./multi_MSD_parameter_0.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)

fig, ax1 = plt.subplots()
color = 'tab:red'

ax1.plot(mul_mi0, wert_mi0, linestyle = 'None', label = 'MI', marker = '.', color=color)
ax1.set_xlabel('Parameter Wert', fontsize = 13)
ax1.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax1.tick_params(axis='y', labelcolor=color)

color = 'tab:blue'
ax2 = ax1.twinx()

ax2.plot(mul_msd0, wert_msd0, linestyle = 'None', label = 'MSD', marker = '.', color=color)
ax2.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Parameter 0 (Translation); Multimodal", fontsize = 15)
plt.legend(loc="best")

plt.show()

# %%
mul_mi4, wert_mi4 = np.loadtxt('./multi_MI_parameter_4.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)
mul_msd4, wert_msd4 = np.loadtxt('./multi_MSD_parameter_4.txt', usecols = (0,1), delimiter=',,,,,,,,,,', unpack = True)

fig, ax1 = plt.subplots()
color = 'tab:red'

ax1.plot(mul_mi4, wert_mi4, linestyle = 'None', label = 'MI', marker = '.', color=color)
ax1.set_xlabel('Parameter Wert', fontsize = 13)
ax1.set_ylabel('Metrik Wert', fontsize = 13, color=color)

color = 'tab:blue'
ax2 = ax1.twinx()

ax2.plot(mul_msd4, wert_msd4, linestyle = 'None', label = 'MSD', marker = '.', color=color)
ax2.set_ylabel('Metrik Wert', fontsize = 13, color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.title("Parameter 4 (Translation); Multimodal", fontsize = 15)
plt.legend(loc="best")



plt.show()
